# %% [markdown]
# So you are minimizing the loss function
# L = F(Y_actual - Y_Predict) ; This Y_predict == you got by the linear combo of input features (or w*X)
# so what we are doing in the training process is we tend to make w higher.
# - whats the problem then
# shooting of the high param value may be due to some outliers and our model trying to fit that outliers gives us a completely different result so keeping a check over the magnitude of the param is what we call the regularization.
#
# so now we want to check the value of magnitude of the param.
# we do L2-reg or famously Ridge regression
# L = F(Y_actual - Y_predict) +  k * w^2
# so lets code and see the result

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(42)

# %%
# generate linear data points x and y // generating 100 points
X = np.linspace(0, 10, 100)
error = np.random.normal(0,1 ,100) # choosing deviation from the normal distributions and adding them to the X to get the Y.
Y = X + error # labels for our 1D data

X = X.reshape((100,1))
Y  = Y.reshape((100,1))

# %%
# Visualise the data points
plt.scatter(X , Y)

# %% [markdown]
# As the Loss function has cahnged there will be a change in the weight update equations lets calcualte
#
# L = (y - wx)^2 + k*w^2  ; k is the regularization param
# lets now calculate the dL/dw
# dL/dw = -2*x(y-wx) + 2kw
# and that's it lets write the update equations

# %%
# weights intialize 
w = 0

# %%
Y_predict = w*X
# for the ridge regression there should be a change in the update by the gradient descent

# %%
L_MSE = np.sum((Y - Y_predict)**2)  / 100
print("Loss for our data: " , L_MSE)
# Out:
# Loss for our data:  33.525056608312035

# %%
# w = w -  ( -2lx(y-wx) + 2kw)


l = 0.00001  # be very very carefull in choosing the right value it take me 1hr to figure out the bug
k = 0.001 
w  = w  + 2*l*(X.T)@(Y - Y_predict) + 2*k*w
print(w)
# Out:
# [[0.06619943]]

# %%
w = 0 
for i in range(200):
    # forward pass code:
    Y_predict = w*X 
    L_MSE = np.sum((Y - Y_predict)**2) / 100 + int(k*w**2)
    print(f"{i}th iteration : " , L_MSE)

    # Backward pass i.e Backpropagation :
    l = 0.00001 
    k =  0.0001
    w  = w  + 2*l*(X.T)@(Y - Y_predict) + 2*k*w
# Out:
# 0th iteration :  33.525056608312035
# 1th iteration :  29.28950817721398
# 2th iteration :  25.601773521418885
# 3th iteration :  22.391051114614683
# 4th iteration :  19.595686676060957
# 5th iteration :  17.161991614461723
# 6th iteration :  15.043214079064494
# 7th iteration :  13.198642908582721
# 8th iteration :  11.592827313963983
# 9th iteration :  10.194897347719197
# 10th iteration :  8.977972142944616
# 11th iteration :  7.918644586278062
# 12th iteration :  6.996532553032039
# 13th iteration :  6.193888107676197
# 14th iteration :  5.4952571831189125
# 15th iteration :  4.887183219125845
# 16th iteration :  4.357949082230601
# 17th iteration :  3.8973523227658493
# 18th iteration :  3.4965094632156064
# 19th iteration :  3.147685568191888
# 20th iteration :  2.8441458306214917
# 21th iteration :  2.5800263304671875
# 22th iteration :  2.3502214895789315
# 23th iteration :  2.1502860661093384
# 24th iteration :  1.9763498104594148
# 25th iteration :  1.8250431472797897
# 26th iteration :  1.693432459285521
# 27th iteration :  1.5789637325944508
# 28th iteration :  1.4794134834933397
# 29th iteration :  1.3928460260410551
# 30th iteration :  1.3175762614055655
# 31th iteration :  1.2521372756286788
# 32th iteration :  1.1952521246455219
# 33th iteration :  1.1458092656194274
# 34th iteration :  1.1028411635240547
# 35th iteration :  1.065505662751467
# 36th iteration :  1.033069766512986
# 37th iteration :  1.0048955129439985
# 38th iteration :  0.9804276770082789
# 39th iteration :  0.9591830622916026
# 40th iteration :  0.9407411772488061
# 41th iteration :  0.9247361170066624
# 42th iteration :  0.9108494949354502
# 43th iteration :  0.8988042883275236
# 44th iteration :  0.8883594800471415
# 45th iteration :  0.8793053932779523
# 46th iteration :  0.8714596297853099
# 47th iteration :  0.8646635336845857
# 48th iteration :  0.8587791127855913
# 49th iteration :  0.8536863583602344
# 50th iteration :  0.8492809118237635
# 51th iteration :  0.8454720334758327
# 52th iteration :  0.8421808342436888
# 53th iteration :  0.839338736417086
# 54th iteration :  0.8368861337597998
# 55th iteration :  0.8347712252100494
# 56th iteration :  0.8329489997150873
# 57th iteration :  0.8313803526475797
# 58th iteration :  0.8300313167787579
# 59th iteration :  0.8288723929841351
# 60th iteration :  0.8278779677740548
# 61th iteration :  0.8270258064101299
# 62th iteration :  0.8262966118218367
# 63th iteration :  0.8256736408029045
# 64th iteration :  0.8251423700690127
# 65th iteration :  0.8246902057177747
# 66th iteration :  0.8243062304674497
# 67th iteration :  0.823980983778298
# 68th iteration :  0.8237062705939544
# 69th iteration :  0.8234749949917436
# 70th iteration :  0.8232810155111355
# 71th iteration :  0.8231190193477087
# 72th iteration :  0.8229844129640889
# 73th iteration :  0.8228732269863621
# 74th iteration :  0.8227820335304874
# 75th iteration :  0.8227078743435672
# 76th iteration :  0.8226481983540775
# 77th iteration :  0.8226008074073392
# 78th iteration :  0.8225638091211264
# 79th iteration :  0.8225355759343889
# 80th iteration :  0.8225147095422995
# 81th iteration :  0.8225000100154759
# 82th iteration :  0.8224904489923603
# 83th iteration :  0.8224851464130496
# 84th iteration :  0.8224833503319081
# 85th iteration :  0.8224844194064117
# 86th iteration :  0.8224878077119823
# 87th iteration :  0.8224930515781161
# 88th iteration :  0.8224997581807421
# 89th iteration :  0.8225075956602498
# 90th iteration :  0.8225162845646582
# 91th iteration :  0.822525590443513
# 92th iteration :  0.8225353174408561
# 93th iteration :  0.8225453027554025
# 94th iteration :  0.8225554118532592
# 95th iteration :  0.8225655343335322
# 96th iteration :  0.822575580360187
# 97th iteration :  0.8225854775848727
# 98th iteration :  0.8225951684952973
# 99th iteration :  0.8226046081323054
# 100th iteration :  0.8226137621262974
# 101th iteration :  0.8226226050101082
# 102th iteration :  0.8226311187711149
# 103th iteration :  0.822639291610247
# 104th iteration :  0.8226471168798597
# 105th iteration :  0.8226545921761169
# 106th iteration :  0.8226617185647795
# 107th iteration :  0.8226684999220859
# 108th iteration :  0.8226749423748507
# 109th iteration :  0.8226810538260293
# 110th iteration :  0.8226868435538299
# 111th iteration :  0.8226923218740562
# 112th iteration :  0.8226974998567461
# 113th iteration :  0.822702389089386
# 114th iteration :  0.8227070014800133
# 115th iteration :  0.8227113490944375
# 116th iteration :  0.8227154440225912
# 117th iteration :  0.8227192982697075
# 118th iteration :  0.8227229236686151
# 119th iteration :  0.822726331809948
# 120th iteration :  0.8227295339875177
# 121th iteration :  0.8227325411564789
# 122th iteration :  0.8227353639022548
# 123th iteration :  0.822738012418472
# 124th iteration :  0.8227404964924078
# 125th iteration :  0.8227428254966721
# 126th iteration :  0.8227450083860209
# 127th iteration :  0.8227470536983756
# 128th iteration :  0.8227489695592445
# 129th iteration :  0.822750763688876
# 130th iteration :  0.822752443411567
# 131th iteration :  0.8227540156666437
# 132th iteration :  0.8227554870207073
# 133th iteration :  0.822756863680802
# 134th iteration :  0.8227581515082163
# 135th iteration :  0.8227593560326832
# 136th iteration :  0.8227604824667816
# 137th iteration :  0.8227615357203747
# 138th iteration :  0.8227625204149573
# 139th iteration :  0.8227634408978003
# 140th iteration :  0.8227643012558145
# 141th iteration :  0.8227651053290621
# 142th iteration :  0.8227658567238685
# 143th iteration :  0.8227665588254909
# 144th iteration :  0.8227672148103252
# 145th iteration :  0.8227678276576252
# 146th iteration :  0.8227684001607294
# 147th iteration :  0.8227689349377877
# 148th iteration :  0.8227694344419892
# 149th iteration :  0.8227699009713002
# 150th iteration :  0.8227703366777142
# 151th iteration :  0.8227707435760291
# 152th iteration :  0.8227711235521666
# 153th iteration :  0.8227714783710417
# 154th iteration :  0.8227718096840022
# 155th iteration :  0.8227721190358583
# 156th iteration :  0.8227724078715092
# 157th iteration :  0.8227726775421941
# 158th iteration :  0.8227729293113795
# 159th iteration :  0.822773164360299
# 160th iteration :  0.8227733837931686
# 161th iteration :  0.8227735886420853
# 162th iteration :  0.8227737798716325
# 163th iteration :  0.8227739583832068
# 164th iteration :  0.8227741250190758
# 165th iteration :  0.8227742805661871
# 166th iteration :  0.8227744257597442
# 167th iteration :  0.8227745612865546
# 168th iteration :  0.8227746877881699
# 169th iteration :  0.8227748058638287
# 170th iteration :  0.822774916073214
# 171th iteration :  0.8227750189390324
# 172th iteration :  0.822775114949432
# 173th iteration :  0.8227752045602647
# 174th iteration :  0.8227752881972027
# 175th iteration :  0.8227753662577194
# 176th iteration :  0.822775439112943
# 177th iteration :  0.8227755071093888
# 178th iteration :  0.822775570570581
# 179th iteration :  0.8227756297985684
# 180th iteration :  0.8227756850753402
# 181th iteration :  0.8227757366641515
# 182th iteration :  0.8227757848107623
# 183th iteration :  0.8227758297445922
# 184th iteration :  0.8227758716798048
# 185th iteration :  0.8227759108163157
# 186th iteration :  0.8227759473407369
# 187th iteration :  0.8227759814272604
# 188th iteration :  0.8227760132384796
# 189th iteration :  0.8227760429261621
# 190th iteration :  0.8227760706319657
# 191th iteration :  0.8227760964881108
# 192th iteration :  0.8227761206180084
# 193th iteration :  0.8227761431368443
# 194th iteration :  0.8227761641521276
# 195th iteration :  0.8227761837641995
# 196th iteration :  0.8227762020667113
# 197th iteration :  0.8227762191470696
# 198th iteration :  0.8227762350868515
# 199th iteration :  0.8227762499621939
# /tmp/ipykernel_31779/352904361.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   L_MSE = np.sum((Y - Y_predict)**2) / 100 + int(k*w**2)

# %%
# By linear algebra lets obtain the weight

# %%
print("The Optimum param by L2-reg : ", w)
# Out:
# The Optimum param by L2-reg :  [[0.99095856]]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# above the lambda is the regularizing param or K in our case

# lets calculate the weight 
W_rs = np.linalg.inv(X.T@X  + k*np.identity(1)) @ X.T @ Y

# %%
W_ls = np.linalg.inv(X.T@X) @ X.T @ Y

# %%
print("The Optimum param by L2-reg : ", w)
print("The Optimum param by linear algebra formulae : ", W_rs)
print("The Optimum param by linear algebra formulae for linear regression: ", W_ls)
# Out:
# The Optimum param by L2-reg :  [[0.99095856]]
# The Optimum param by linear algebra formulae :  [[0.98800157]]
# The Optimum param by linear algebra formulae for linear regression:  [[0.9880016]]

# %%
# Lets now visualise the ouput 

plt.scatter(X , Y)
plt.scatter(X, w*X , c = 'r')
plt.scatter(X, W_rs*X , c = 'g')
plt.scatter(X, W_ls*X , c = 'b')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### One Attempt to implement the Lasso Regression or the L1-regularizer

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# IF we tried to get the derivative of it then
# dL/dw  = -2*x*(y-y_predict) + k

# %%
W_lasso = 0 
l_lasso = 0.0001
for i in range(200):
    # forward pass code:
    Y_predict = W_lasso*X 
    L_MSE = np.sum((Y - Y_predict)**2) / 100 + int(l_lasso*W_lasso)
    print(f"{i}th iteration : " , L_MSE)

    # Backward pass i.e Backpropagation :
    l = 0.00001 
    # k =  0.0001
    W_lasso  = W_lasso  + 2*l*(X.T)@(Y - Y_predict) + l_lasso
# Out:
# 0th iteration :  33.525056608312035
# 1th iteration :  29.283332127345144
# 2th iteration :  25.591398739333624
# 3th iteration :  22.378021225336013
# 4th iteration :  19.58119241912371
# 5th iteration :  17.146937890193694
# 6th iteration :  15.02827544934325
# 7th iteration :  13.18430942404924
# 8th iteration :  11.579442248110915
# 9th iteration :  10.182688170844356
# 10th iteration :  8.967075859127124
# 11th iteration :  7.909128378708569
# 12th iteration :  6.988410532437863
# 13th iteration :  6.1871348311556265
# 14th iteration :  5.489818502961391
# 15th iteration :  4.882984930183764
# 16th iteration :  4.354903759598158
# 17th iteration :  3.8953646767583585
# 18th iteration :  3.4954804840963707
# 19th iteration :  3.1475156872026093
# 20th iteration :  2.8447372853090034
# 21th iteration :  2.5812848899350023
# 22th iteration :  2.3520576681675895
# 23th iteration :  2.1526159313098883
# 24th iteration :  1.9790954718978468
# 25th iteration :  1.8281329977903993
# 26th iteration :  1.6968012259204273
# 27th iteration :  1.582552384473682
# 28th iteration :  1.4831690343284774
# 29th iteration :  1.3967212616636695
# 30th iteration :  1.3215294164449727
# 31th iteration :  1.2561316783965482
# 32th iteration :  1.1992558251162726
# 33th iteration :  1.149794657992202
# 34th iteration :  1.106784612085727
# 35th iteration :  1.0693871375224235
# 36th iteration :  1.036872493357546
# 37th iteration :  1.0086056413891225
# 38th iteration :  0.9840339678739446
# 39th iteration :  0.962676596340602
# 40th iteration :  0.9441150853682396
# 41th iteration :  0.927985331901089
# 42th iteration :  0.9139705239116495
# 43th iteration :  0.9017950064576378
# 44th iteration :  0.8912189427894215
# 45th iteration :  0.882033667495036
# 46th iteration :  0.8740576420145146
# 47th iteration :  0.8671329344713726
# 48th iteration :  0.8611221558805255
# 49th iteration :  0.8559057935935946
# 50th iteration :  0.8513798905041348
# 51th iteration :  0.8474540252044251
# 52th iteration :  0.8440495540907059
# 53th iteration :  0.8410980814669692
# 54th iteration :  0.8385401280960556
# 55th iteration :  0.8363239724756513
# 56th iteration :  0.8344046424496058
# 57th iteration :  0.8327430376661004
# 58th iteration :  0.8313051659194433
# 59th iteration :  0.8300614786104061
# 60th iteration :  0.8289862924733481
# 61th iteration :  0.8280572863838733
# 62th iteration :  0.8272550635104414
# 63th iteration :  0.8265627703352517
# 64th iteration :  0.8259657651681025
# 65th iteration :  0.8254513297330069
# 66th iteration :  0.8250084182395463
# 67th iteration :  0.8246274390753122
# 68th iteration :  0.8243000648863094
# 69th iteration :  0.8240190673609835
# 70th iteration :  0.8237781735112493
# 71th iteration :  0.8235719406596671
# 72th iteration :  0.8233956477038366
# 73th iteration :  0.8232452005440688
# 74th iteration :  0.8231170498345736
# 75th iteration :  0.8230081194570549
# 76th iteration :  0.8229157443232903
# 77th iteration :  0.8228376162940783
# 78th iteration :  0.8227717371592719
# 79th iteration :  0.8227163777605662
# 80th iteration :  0.8226700424579146
# 81th iteration :  0.8226314382441633
# 82th iteration :  0.8225994479028119
# 83th iteration :  0.8225731066823552
# 84th iteration :  0.8225515820290746
# 85th iteration :  0.8225341559796465
# 86th iteration :  0.8225202098667442
# 87th iteration :  0.8225092110358757
# 88th iteration :  0.8225007013109397
# 89th iteration :  0.8224942869801092
# 90th iteration :  0.8224896301033665
# 91th iteration :  0.8224864409688579
# 92th iteration :  0.8224844715477405
# 93th iteration :  0.8224835098167549
# 94th iteration :  0.8224833748348034
# 95th iteration :  0.8224839124746205
# 96th iteration :  0.8224849917235254
# 97th iteration :  0.8224865014784589
# 98th iteration :  0.8224883477702734
# 99th iteration :  0.822490451360727
# 100th iteration :  0.8224927456630298
# 101th iteration :  0.8224951749432095
# 102th iteration :  0.8224976927651549
# 103th iteration :  0.8225002606470592
# 104th iteration :  0.8225028469012108
# 105th iteration :  0.8225054256327633
# 106th iteration :  0.8225079758763055
# 107th iteration :  0.8225104808518456
# 108th iteration :  0.8225129273242269
# 109th iteration :  0.822515305052115
# 110th iteration :  0.8225176063145055
# 111th iteration :  0.822519825504301
# 112th iteration :  0.8225219587798894
# 113th iteration :  0.8225240037668498
# 114th iteration :  0.8225259593029537
# 115th iteration :  0.8225278252205528
# 116th iteration :  0.8225296021612079
# 117th iteration :  0.8225312914181169
# 118th iteration :  0.8225328948024889
# 119th iteration :  0.8225344145305203
# 120th iteration :  0.8225358531280891
# 121th iteration :  0.8225372133506638
# 122th iteration :  0.8225384981162641
# 123th iteration :  0.8225397104496044
# 124th iteration :  0.8225408534358029
# 125th iteration :  0.8225419301822618
# 126th iteration :  0.8225429437875162
# 127th iteration :  0.82254389731601
# 128th iteration :  0.8225447937779051
# 129th iteration :  0.8225456361131569
# 130th iteration :  0.8225464271791878
# 131th iteration :  0.8225471697415939
# 132th iteration :  0.8225478664673933
# 133th iteration :  0.8225485199204
# 134th iteration :  0.8225491325583589
# 135th iteration :  0.8225497067315434
# 136th iteration :  0.8225502446825458
# 137th iteration :  0.8225507485470439
# 138th iteration :  0.8225512203553507
# 139th iteration :  0.8225516620345859
# 140th iteration :  0.8225520754113377
# 141th iteration :  0.8225524622146944
# 142th iteration :  0.8225528240795544
# 143th iteration :  0.8225531625501319
# 144th iteration :  0.8225534790835887
# 145th iteration :  0.8225537750537424
# 146th iteration :  0.8225540517548003
# 147th iteration :  0.8225543104050801
# 148th iteration :  0.8225545521506947
# 149th iteration :  0.8225547780691688
# 150th iteration :  0.8225549891729713
# 151th iteration :  0.8225551864129489
# 152th iteration :  0.8225553706816509
# 153th iteration :  0.8225555428165339
# 154th iteration :  0.8225557036030424
# 155th iteration :  0.822555853777564
# 156th iteration :  0.8225559940302528
# 157th iteration :  0.8225561250077252
# 158th iteration :  0.8225562473156266
# 159th iteration :  0.8225563615210721
# 160th iteration :  0.822556468154962
# 161th iteration :  0.8225565677141775
# 162th iteration :  0.8225566606636597
# 163th iteration :  0.822556747438373
# 164th iteration :  0.8225568284451633
# 165th iteration :  0.8225569040645069
# 166th iteration :  0.822556974652164
# 167th iteration :  0.8225570405407328
# 168th iteration :  0.8225571020411155
# 169th iteration :  0.8225571594438938
# 170th iteration :  0.8225572130206251
# 171th iteration :  0.8225572630250605
# 172th iteration :  0.8225573096942854
# 173th iteration :  0.822557353249795
# 174th iteration :  0.822557393898498
# 175th iteration :  0.8225574318336639
# 176th iteration :  0.822557467235805
# 177th iteration :  0.8225575002735082
# 178th iteration :  0.8225575311042114
# 179th iteration :  0.8225575598749308
# 180th iteration :  0.8225575867229449
# 181th iteration :  0.8225576117764293
# 182th iteration :  0.8225576351550568
# 183th iteration :  0.822557656970555
# 184th iteration :  0.8225576773272284
# 185th iteration :  0.8225576963224506
# 186th iteration :  0.8225577140471166
# 187th iteration :  0.8225577305860751
# 188th iteration :  0.8225577460185258
# 189th iteration :  0.8225577604183936
# 190th iteration :  0.8225577738546777
# 191th iteration :  0.8225577863917795
# 192th iteration :  0.8225577980898051
# 193th iteration :  0.8225578090048525
# 194th iteration :  0.8225578191892763
# 195th iteration :  0.822557828691937
# 196th iteration :  0.8225578375584344
# 197th iteration :  0.8225578458313223
# 198th iteration :  0.8225578535503131
# 199th iteration :  0.8225578607524661
# /tmp/ipykernel_31779/798990856.py:6: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   L_MSE = np.sum((Y - Y_predict)**2) / 100 + int(l_lasso*W_lasso)

# %%
print("The Optimum param by L1-reg : ", W_lasso)
# Out:
# The Optimum param by L1-reg :  [[0.98949313]]

# %% [markdown]
# It's derivative form can be obtained as the L1-reg tries to minimizes the
# L_MSE  + k*L1-norm(W)
# as we Know that the norm is non diffrentiable so we didn't get the closed form solution of the equations as we got in case of Ridge regression
